# %%
import pandas as pd
import os
file_path =  os.path.join(os.path.abspath(os.path.dirname("../dataset/")), 'housing_data.csv')
df = pd.read_csv(file_path)
df.head()
# Out:
#    Unnamed: 0 MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0           0       SC60       RL         65.0     8450   Pave   NaN      Reg
# 1           1       SC20       RL         80.0     9600   Pave   NaN      Reg
# 2           2       SC60       RL         68.0    11250   Pave   NaN      IR1
# 3           3       SC70       RL         60.0     9550   Pave   NaN      IR1
# 4           4       SC60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0     No    No          No       0    Feb
# 1         Lvl    AllPub  ...        0     No    No          No       0    May
# 2         Lvl    AllPub  ...        0     No    No          No       0    Sep
# 3         Lvl    AllPub  ...        0     No    No          No       0    Feb
# 4         Lvl    AllPub  ...        0     No    No          No       0    Dec
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     1460 non-null   int64
#  1   MSSubClass     1460 non-null   object
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1460 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
df.describe()
# Out:
#         Unnamed: 0  LotFrontage        LotArea  OverallQual  OverallCond  \
# count  1460.000000  1460.000000    1460.000000  1460.000000  1460.000000
# mean    729.500000    57.623288   10516.828082     6.099315     5.575342
# std     421.610009    34.664304    9981.264932     1.382997     1.112799
# min       0.000000     0.000000    1300.000000     1.000000     1.000000
# 25%     364.750000    42.000000    7553.500000     5.000000     5.000000
# 50%     729.500000    63.000000    9478.500000     6.000000     5.000000
# 75%    1094.250000    79.000000   11601.500000     7.000000     6.000000
# max    1459.000000   313.000000  215245.000000    10.000000     9.000000
#
#          YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1   BsmtFinSF2  ...  \
# count  1460.000000   1460.000000  1460.000000  1460.000000  1460.000000  ...
# mean   1971.267808   1984.865753   103.117123   443.639726    46.549315  ...
# std      30.202904     20.645407   180.731373   456.098091   161.319273  ...
# ...

# %%
selected_columns = ['LotArea', 'YearBuilt', '1stFlrSF', '2ndFlrSF', 'SalePrice']
df[selected_columns].describe()
# Out:
#              LotArea    YearBuilt     1stFlrSF     2ndFlrSF      SalePrice
# count    1460.000000  1460.000000  1460.000000  1460.000000    1460.000000
# mean    10516.828082  1971.267808  1162.626712   346.992466  180921.195890
# std      9981.264932    30.202904   386.587738   436.528436   79442.502883
# min      1300.000000  1872.000000   334.000000     0.000000   34900.000000
# 25%      7553.500000  1954.000000   882.000000     0.000000  129975.000000
# 50%      9478.500000  1973.000000  1087.000000     0.000000  163000.000000
# 75%     11601.500000  2000.000000  1391.250000   728.000000  214000.000000
# max    215245.000000  2010.000000  4692.000000  2065.000000  755000.000000

# %%
df[selected_columns].corr()
# Out:
#             LotArea  YearBuilt  1stFlrSF  2ndFlrSF  SalePrice
# LotArea    1.000000   0.014228  0.299475  0.050986   0.263843
# YearBuilt  0.014228   1.000000  0.281986  0.010308   0.522897
# 1stFlrSF   0.299475   0.281986  1.000000 -0.202646   0.605852
# 2ndFlrSF   0.050986   0.010308 -0.202646  1.000000   0.319334
# SalePrice  0.263843   0.522897  0.605852  0.319334   1.000000

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea',
#        'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
# ...

# %%
# Install and import matplotlib
# %pip install matplotlib
import matplotlib.pyplot as plt

# Plot the data
df['Neighborhood'].value_counts()
df['Neighborhood'].value_counts().plot(kind='bar', figsize=(10, 5), color='skyblue')
plt.show()
# Out:
# ...
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    -------------------------- ------------- 5.2/8.1 MB 26.5 MB/s eta 0:00:01
#    ---------------------------------------- 8.1/8.1 MB 26.2 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 2.2/2.2 MB 24.9 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.1
# [notice] To update, run: C:\Users\prate\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
# Plot the data
df['BldgType'].value_counts()
df['BldgType'].value_counts().plot(kind='bar', figsize=(10, 5), color='skyblue')
plt.show()

# %%
# Plot the data
df['HouseStyle'].value_counts()
df['HouseStyle'].value_counts().plot(kind='bar', figsize=(10, 5), color='skyblue')
plt.show()

# %%
print(df[selected_columns].corr().unstack())
# Out:
# LotArea    LotArea      1.000000
#            YearBuilt    0.014228
#            1stFlrSF     0.299475
#            2ndFlrSF     0.050986
#            SalePrice    0.263843
# YearBuilt  LotArea      0.014228
#            YearBuilt    1.000000
#            1stFlrSF     0.281986
#            2ndFlrSF     0.010308
#            SalePrice    0.522897
# 1stFlrSF   LotArea      0.299475
#            YearBuilt    0.281986
#            1stFlrSF     1.000000
#            2ndFlrSF    -0.202646
#            SalePrice    0.605852
# 2ndFlrSF   LotArea      0.050986
#            YearBuilt    0.010308
#            1stFlrSF    -0.202646
#            2ndFlrSF     1.000000
#            SalePrice    0.319334
# SalePrice  LotArea      0.263843
#            YearBuilt    0.522897
#            1stFlrSF     0.605852
#            2ndFlrSF     0.319334
#            SalePrice    1.000000
# dtype: float64

# %%
correlations = [
    df[selected_columns].corr(),
    df[selected_columns].corr(method='spearman'),
    df[selected_columns].corr(method='pearson')
]
#%pip install seaborn
import seaborn as sns
import matplotlib.pyplot as plt
# Set the size of the plot
for data in correlations:
    print(data)
    try:
        plt.figure(figsize=(10, 6))
        # Create a heatmap using seaborn
        sns.heatmap(data, annot=True, cmap='coolwarm', fmt='.2f')
        plt.title('Correlation Heatmap of Selected Features')
        plt.show()
    except Exception as e:
        print(f"Error plotting heatmap: {e}")
        continue
# Out:
#             LotArea  YearBuilt  1stFlrSF  2ndFlrSF  SalePrice
# LotArea    1.000000   0.014228  0.299475  0.050986   0.263843
# YearBuilt  0.014228   1.000000  0.281986  0.010308   0.522897
# 1stFlrSF   0.299475   0.281986  1.000000 -0.202646   0.605852
# 2ndFlrSF   0.050986   0.010308 -0.202646  1.000000   0.319334
# SalePrice  0.263843   0.522897  0.605852  0.319334   1.000000
#             LotArea  YearBuilt  1stFlrSF  2ndFlrSF  SalePrice
# LotArea    1.000000   0.103385  0.443858  0.119356   0.456461
# YearBuilt  0.103385   1.000000  0.293363  0.029716   0.652682
# 1stFlrSF   0.443858   0.293363  1.000000 -0.276218   0.575408
# 2ndFlrSF   0.119356   0.029716 -0.276218  1.000000   0.293598
# SalePrice  0.456461   0.652682  0.575408  0.293598   1.000000
#             LotArea  YearBuilt  1stFlrSF  2ndFlrSF  SalePrice
# LotArea    1.000000   0.014228  0.299475  0.050986   0.263843
# YearBuilt  0.014228   1.000000  0.281986  0.010308   0.522897
# ...
